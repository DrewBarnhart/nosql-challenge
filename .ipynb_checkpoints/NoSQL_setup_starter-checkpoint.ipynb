# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies

from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
#print(mongo.uk_food)
# Out:
# ['admin', 'autosaurus', 'config', 'gardendb', 'local', 'uk_food', 'uk_food1']

# %%
# assign the uk_food database to a variable name
uk_food_db = mongo['uk_food']
# uk_food_db

# %%
establishments = uk_food_db["establishments"]

# %%
# review the collections in our new database
print(uk_food_db.list_collection_names())
# Out:
# ['establishments', 'variable']

# %%
# review a document in the establishments collection
pprint(uk_food_db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6409334d3b86c0dfb8af0d6e'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
#variable = (uk_food_db.establishments.find_one())
variable =uk_food_db['establishments']
variable
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
restaurant= {
"BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}
restaurant
# Out:
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(restaurant)
#uk_food_db.variable.insert_one(restaurant)

# %%
pprint(establishments.find_one({"BusinessName":"Penang Flavours"}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'BussinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('640937d77adc30b57f1c2b78'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Check that the new restaurant was inserted

establishments.find_one({'BusinessName': 'Penang Flavours'})

# uk_food_db.variable.find_one({'BusinessName': 'Penang Flavours'})
# Out:
# {'_id': ObjectId('640937d77adc30b57f1c2b78'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.08384, 'latitude': 51.490142},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True,
#  'BussinessTypeID': 1}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" 
# and return only the BusinessTypeID and BusinessType fields

query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BussinessTypeID':1, 'BussinessType':1 }

pprint(establishments.find_one(query,projection= fields))
# Out:
# {'_id': ObjectId('6409334d3b86c0dfb8af0d6e')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# # Capture the results to a variable
# results = list(establishments.find(query, fields))

# # Pretty print the results
# for result in results:
#     pprint(result)

#result was really long, un comment out above-code to display objectID's
# Out:
# {'_id': ObjectId('6409334d3b86c0dfb8af0d6e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d79')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d7d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d81')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d82')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d91')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d97')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d9a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d9e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0d9f')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0da2')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0da3')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0db3')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dba')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dbc')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dc2')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dc6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dc7')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dca')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dcc')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dcf')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dd1')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dd2')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dd3')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dd4')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ddb')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ddd')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dde')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0de3')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0de5')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0de6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0de7')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dec')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dee')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0df7')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0df8')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dfa')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dfe')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0dff')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e02')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e03')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e07')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e0b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e0c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e0e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e10')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e14')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e15')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e17')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e1b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e1d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e21')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e22')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e27')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e2a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e2c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e34')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e35')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e37')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e3f')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e40')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e41')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e47')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e49')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e4b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e4d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e53')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e54')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e56')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e57')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e58')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e59')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e5c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e61')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e63')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e64')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e66')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e73')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e74')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e77')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e78')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e7a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e80')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e81')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e84')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e86')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e88')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e89')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e8f')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e92')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e94')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0e9a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ea4')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ebc')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ec0')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ec2')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ec9')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0eca')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ee6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ef1')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ef2')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ef3')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ef6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f00')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f03')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f04')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f05')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f06')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f08')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f0b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f0c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f0d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f0e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f0f')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f15')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f22')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f26')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f27')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f28')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f29')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f2a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f2b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f2d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f2e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f30')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f33')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f35')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f39')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f3b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f43')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f44')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f45')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f46')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f47')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f48')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f4d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f4e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f59')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f5a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f5c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f5d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f5f')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f61')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f6a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f6e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f70')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f75')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f77')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f7c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f7e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f7f')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f82')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f8a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f90')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f96')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f9b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0f9e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fa0')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fa4')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fa7')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0faa')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fb2')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fb6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fb9')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fba')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fbc')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fbd')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fc1')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fc7')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fca')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fcb')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fce')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fd5')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fd8')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fda')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fde')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fe1')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fe2')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fe3')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fe4')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fe5')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fe6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fe8')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fe9')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0feb')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fec')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0fef')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ff0')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ff1')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ff2')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ff4')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ff7')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ff8')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ff9')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ffa')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ffc')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ffd')}
# {'_id': ObjectId('6409334d3b86c0dfb8af0ffe')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1000')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1001')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1004')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1006')}
# {'_id': ObjectId('6409334d3b86c0dfb8af100e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1010')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1011')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1012')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1013')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1015')}
# {'_id': ObjectId('6409334d3b86c0dfb8af101d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af101e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1021')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1023')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1025')}
# {'_id': ObjectId('6409334d3b86c0dfb8af102a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af102c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1033')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1035')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1042')}
# {'_id': ObjectId('6409334d3b86c0dfb8af104c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1054')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1059')}
# {'_id': ObjectId('6409334d3b86c0dfb8af105e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1061')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1069')}
# {'_id': ObjectId('6409334d3b86c0dfb8af106e')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1075')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1076')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1078')}
# {'_id': ObjectId('6409334d3b86c0dfb8af107b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af107c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af107d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1081')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1084')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1089')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1096')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1097')}
# {'_id': ObjectId('6409334d3b86c0dfb8af109c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af109f')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10a6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10a9')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10b1')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10b9')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10cf')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10de')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10df')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10e0')}
# {'_id': ObjectId('6409334d3b86c0dfb8af10ea')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1103')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1108')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1109')}
# {'_id': ObjectId('6409334d3b86c0dfb8af110a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af110b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af111b')}
# {'_id': ObjectId('6409334d3b86c0dfb8af111c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af111d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1124')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1128')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1151')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1152')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1154')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1158')}
# {'_id': ObjectId('6409334d3b86c0dfb8af115c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af115d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1163')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1165')}
# {'_id': ObjectId('6409334d3b86c0dfb8af116a')}
# {'_id': ObjectId('6409334d3b86c0dfb8af116c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1173')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1174')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1176')}
# {'_id': ObjectId('6409334d3b86c0dfb8af117d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1190')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1192')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1194')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1198')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1199')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11a4')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11a7')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11a8')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11b0')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11b6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11bf')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11c7')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11cd')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11d0')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11d3')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11d4')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11de')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11e5')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11e6')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11e8')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11ee')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11f4')}
# {'_id': ObjectId('6409334d3b86c0dfb8af11f8')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1201')}
# {'_id': ObjectId('6409334d3b86c0dfb8af120d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1212')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1213')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1220')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1223')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1228')}
# {'_id': ObjectId('6409334d3b86c0dfb8af122c')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1231')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1232')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1240')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1243')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1244')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1246')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1248')}
# {'_id': ObjectId('6409334d3b86c0dfb8af124d')}
# {'_id': ObjectId('6409334d3b86c0dfb8af1255')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1257')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1258')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1259')}
# {'_id': ObjectId('6409334e3b86c0dfb8af125a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af125c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1261')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1262')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1263')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1264')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1266')}
# {'_id': ObjectId('6409334e3b86c0dfb8af126b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af126e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af126f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1274')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1276')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1277')}
# {'_id': ObjectId('6409334e3b86c0dfb8af127b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af127d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af127e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af127f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1284')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1289')}
# {'_id': ObjectId('6409334e3b86c0dfb8af128c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af128e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1290')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1291')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1292')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1293')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1295')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1296')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1299')}
# {'_id': ObjectId('6409334e3b86c0dfb8af129a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af129b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af129d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af129e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12a3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12a7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12a8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12a9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12ad')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12b2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12b3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12b6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12bd')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12c9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12cd')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12d5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12d6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12e7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12e9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12eb')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12ec')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12ed')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12ee')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12ef')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12fc')}
# {'_id': ObjectId('6409334e3b86c0dfb8af12ff')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1300')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1301')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1304')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1309')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1310')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1312')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1317')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1318')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1319')}
# {'_id': ObjectId('6409334e3b86c0dfb8af131c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af131f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1320')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1326')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1327')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1328')}
# {'_id': ObjectId('6409334e3b86c0dfb8af132c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af133c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1341')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1348')}
# {'_id': ObjectId('6409334e3b86c0dfb8af134d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1356')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1357')}
# {'_id': ObjectId('6409334e3b86c0dfb8af135c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1361')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1363')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1364')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1366')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1368')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1369')}
# {'_id': ObjectId('6409334e3b86c0dfb8af136c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af136d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1378')}
# {'_id': ObjectId('6409334e3b86c0dfb8af137e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af138e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1392')}
# {'_id': ObjectId('6409334e3b86c0dfb8af139a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13ab')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13ad')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13af')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13b2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13b3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13b9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13d8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13db')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13e6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13e7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13e9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13ea')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13ec')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13ee')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13f1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13f4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13fd')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13fe')}
# {'_id': ObjectId('6409334e3b86c0dfb8af13ff')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1405')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1407')}
# {'_id': ObjectId('6409334e3b86c0dfb8af140a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af140e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1412')}
# {'_id': ObjectId('6409334e3b86c0dfb8af141a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af141b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af141d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1420')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1422')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1427')}
# {'_id': ObjectId('6409334e3b86c0dfb8af142f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1431')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1434')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1435')}
# {'_id': ObjectId('6409334e3b86c0dfb8af143a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af143b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1440')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1441')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1445')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1449')}
# {'_id': ObjectId('6409334e3b86c0dfb8af144a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af144b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af144f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1452')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1453')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1456')}
# {'_id': ObjectId('6409334e3b86c0dfb8af145d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af145e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1461')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1462')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1464')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1465')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1467')}
# {'_id': ObjectId('6409334e3b86c0dfb8af146c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af146d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af146e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af146f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1471')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1472')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1473')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1475')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1476')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1477')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1478')}
# {'_id': ObjectId('6409334e3b86c0dfb8af147b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af147d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af147f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1480')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1482')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1485')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1486')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1489')}
# {'_id': ObjectId('6409334e3b86c0dfb8af148a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af148c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af148d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1492')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1493')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1494')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1496')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1498')}
# {'_id': ObjectId('6409334e3b86c0dfb8af149e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14a7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14a9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14aa')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14ac')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14ad')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14ae')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14b0')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14b1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14b2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14b4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14b7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14ba')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14c5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14c6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14c9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14ca')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14cb')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14cc')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14cd')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14cf')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14da')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14db')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14dc')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14de')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14e3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14e4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14e5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14e9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14ed')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14ee')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14f0')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14f3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14f7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af14f9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1500')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1503')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1504')}
# {'_id': ObjectId('6409334e3b86c0dfb8af150e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af150f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1511')}
# {'_id': ObjectId('6409334e3b86c0dfb8af151a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af151b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1520')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1522')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1529')}
# {'_id': ObjectId('6409334e3b86c0dfb8af152a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af152b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1532')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1533')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1538')}
# {'_id': ObjectId('6409334e3b86c0dfb8af153a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1540')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1541')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1542')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1551')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1553')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1554')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1556')}
# {'_id': ObjectId('6409334e3b86c0dfb8af155a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1561')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1569')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1571')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1576')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1583')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1586')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1587')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1588')}
# {'_id': ObjectId('6409334e3b86c0dfb8af158e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1597')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15a1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15a2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15a6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15bb')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15bf')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15c1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15c2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15c3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15c7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15ca')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15cb')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15cc')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15d3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15d5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15d6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15d8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15dd')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15e3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15e4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15ef')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15f1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af15f2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1601')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1602')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1612')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1613')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1614')}
# {'_id': ObjectId('6409334e3b86c0dfb8af161c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1624')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1626')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1628')}
# {'_id': ObjectId('6409334e3b86c0dfb8af162a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af162d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af162f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1636')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1638')}
# {'_id': ObjectId('6409334e3b86c0dfb8af163a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1643')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1647')}
# {'_id': ObjectId('6409334e3b86c0dfb8af164f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1657')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1660')}
# {'_id': ObjectId('6409334e3b86c0dfb8af166a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af166b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af166c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af166f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1674')}
# {'_id': ObjectId('6409334e3b86c0dfb8af167f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1688')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1689')}
# {'_id': ObjectId('6409334e3b86c0dfb8af168b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1692')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1693')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1695')}
# {'_id': ObjectId('6409334e3b86c0dfb8af169a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af169b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af169d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16a6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16a7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16a8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16a9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16b6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16b7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16bc')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16bf')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16c0')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16c3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16c8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16cb')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16d0')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16d4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16e2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16e4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16e8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16ef')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16f4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16f5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af16fa')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1708')}
# {'_id': ObjectId('6409334e3b86c0dfb8af170b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af170f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af171b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1721')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1722')}
# {'_id': ObjectId('6409334e3b86c0dfb8af172c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af172f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1741')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1746')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1747')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1748')}
# {'_id': ObjectId('6409334e3b86c0dfb8af174a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af174f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1751')}
# {'_id': ObjectId('6409334e3b86c0dfb8af175c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1762')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1766')}
# {'_id': ObjectId('6409334e3b86c0dfb8af176c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1773')}
# {'_id': ObjectId('6409334e3b86c0dfb8af177b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af178e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1794')}
# {'_id': ObjectId('6409334e3b86c0dfb8af179a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af179f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17a1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17a9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17aa')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17b2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17b7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17b8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17c5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17c7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17cb')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17cf')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17d1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17d4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17db')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17ec')}
# {'_id': ObjectId('6409334e3b86c0dfb8af17fc')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1806')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1807')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1809')}
# {'_id': ObjectId('6409334e3b86c0dfb8af180d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af180e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1811')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1813')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1816')}
# {'_id': ObjectId('6409334e3b86c0dfb8af181d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af181e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1828')}
# {'_id': ObjectId('6409334e3b86c0dfb8af182a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af182b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af182d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af182e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1832')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1834')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1838')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1839')}
# {'_id': ObjectId('6409334e3b86c0dfb8af183b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af183c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af183d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af183f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1840')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1842')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1844')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1845')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1847')}
# {'_id': ObjectId('6409334e3b86c0dfb8af184a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1850')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1851')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1860')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1861')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1863')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1866')}
# {'_id': ObjectId('6409334e3b86c0dfb8af186b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af186d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1870')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1871')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1872')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1874')}
# {'_id': ObjectId('6409334e3b86c0dfb8af187a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af187c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af187e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af187f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af188b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af188e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af188f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1890')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1892')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1896')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1899')}
# {'_id': ObjectId('6409334e3b86c0dfb8af189a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af189b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af189c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af189d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af189f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18a3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18a6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18a8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18ab')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18ad')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18ae')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18b1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18b4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18b7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18be')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18c0')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18c4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18c7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18c8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18c9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18cb')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18cd')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18cf')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18d2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18d5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18d7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18d8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18db')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18dc')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18dd')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18de')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18e2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18e3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18e5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18e6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18ea')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18ee')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18f0')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18f3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18f4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18f6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18f8')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18f9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af18fa')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1900')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1902')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1903')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1908')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1909')}
# {'_id': ObjectId('6409334e3b86c0dfb8af190d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af190e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af190f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1910')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1911')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1915')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1917')}
# {'_id': ObjectId('6409334e3b86c0dfb8af191b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af191e')}
# {'_id': ObjectId('6409334e3b86c0dfb8af192a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af192b')}
# {'_id': ObjectId('6409334e3b86c0dfb8af192c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af192f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1930')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1932')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1934')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1935')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1938')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1939')}
# {'_id': ObjectId('6409334e3b86c0dfb8af193a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1940')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1941')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1943')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1945')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1946')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1949')}
# {'_id': ObjectId('6409334e3b86c0dfb8af194f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1953')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1954')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1956')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1959')}
# {'_id': ObjectId('6409334e3b86c0dfb8af195a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af195d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af195f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1965')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1967')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1969')}
# {'_id': ObjectId('6409334e3b86c0dfb8af196a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af196c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1972')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1974')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1976')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1978')}
# {'_id': ObjectId('6409334e3b86c0dfb8af197a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af197f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1984')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1985')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1989')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1993')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1994')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1995')}
# {'_id': ObjectId('6409334e3b86c0dfb8af199c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af199d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19a4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19a9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19ac')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19ae')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19b1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19b5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19b9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19ba')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19bb')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19c4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19c5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19ce')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19d0')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19d2')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19d3')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19d4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19d6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19d7')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19da')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19e5')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19e6')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19ef')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19f1')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19f4')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19f9')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19fd')}
# {'_id': ObjectId('6409334e3b86c0dfb8af19ff')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a06')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a07')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a08')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a09')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a0f')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a11')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a1a')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a1c')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a1d')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a20')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a21')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a22')}
# {'_id': ObjectId('6409334e3b86c0dfb8af1a26')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a2b')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a2d')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a2f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a31')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a35')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a3d')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a48')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a4b')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a57')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a58')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a62')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a6e')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a74')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a77')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a7f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a89')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a8d')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a8f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a92')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1a9c')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1aa2')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1aa7')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1aaa')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1aab')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1aaf')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ab1')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ab5')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1abe')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ac2')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ac5')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1aca')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1acb')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1acd')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ad3')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ad9')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1add')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ae6')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ae8')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1af5')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1aff')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b01')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b02')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b0a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b12')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b27')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b2d')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b2e')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b31')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b35')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b38')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b3d')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b4a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b4b')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b4e')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b52')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b53')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b5a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b5c')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b5e')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b62')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b66')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b69')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b6a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b6b')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b6c')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b6f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b70')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b72')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b79')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b7b')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b7c')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b7d')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b81')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b84')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b87')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b89')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b8a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b8f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b90')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b91')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b93')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b94')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b95')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b98')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1b9f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ba6')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ba7')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ba8')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bab')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bac')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bae')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1baf')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bb4')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bb9')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bbb')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bbe')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bc5')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bcb')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bcf')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bd1')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bd3')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bd6')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bdd')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1be3')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1be6')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bec')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bed')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bee')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bf0')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bf3')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bfa')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bfd')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1bff')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c04')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c06')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c07')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c0f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c12')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c14')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c22')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c25')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c2a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c2d')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c35')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c36')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c37')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c38')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c39')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c3e')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c3f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c42')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c43')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c4a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c54')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c55')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c5a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c5f')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c60')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c67')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c69')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c6a')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c6b')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c71')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c72')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c8b')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c8c')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c96')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c9d')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1c9e')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ca1')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ca2')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ca4')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ca5')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ca6')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ca7')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ca8')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cac')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cb0')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cb1')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cb7')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cba')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cbe')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cc7')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cc8')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cc9')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cca')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ccc')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ccd')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cd1')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cd2')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cdb')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cde')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cdf')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ce1')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ce8')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1ce9')}
# {'_id': ObjectId('6409334f3b86c0dfb8af1cea')}
# ...
# {'_id': ObjectId('6409335a3b86c0dfb8afa0d0')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa0e0')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa0e1')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa0eb')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa0fe')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa104')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa106')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa107')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa116')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa11e')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa124')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa126')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa12d')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa133')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa134')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa13a')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa13e')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa140')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa142')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa145')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa152')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa156')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa160')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa161')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa166')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa16a')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa17b')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa17f')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa183')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa184')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa185')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa188')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa18b')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa191')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa192')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa193')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa194')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa197')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1a9')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1ad')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1ae')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1b3')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1cf')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1d0')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1d1')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1d3')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1d4')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1d5')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1d8')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1dc')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1de')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1e5')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1e6')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1e7')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1e8')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1f1')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1f2')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1f4')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1f9')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1fb')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa1fe')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa203')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa204')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa205')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa206')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa208')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa20c')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa212')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa213')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa217')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa219')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa21e')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa223')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa225')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa229')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa22d')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa22f')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa231')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa232')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa233')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa244')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa246')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa248')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa24b')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa24c')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa24e')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa256')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa258')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa25a')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa25d')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa262')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa26d')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa273')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa275')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa27d')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa289')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa292')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa294')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa29f')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2a0')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2a8')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2ad')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2af')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2b2')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2b6')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2be')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2bf')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2c0')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2c2')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2c4')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2c8')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2d2')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2d4')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2d6')}
# {'_id': ObjectId('6409335a3b86c0dfb8afa2dd')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2e1')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2e2')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2e3')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2ef')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2f4')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2f5')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2f7')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2f9')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2fa')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2fb')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa2fd')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa304')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa30c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa310')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa314')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa319')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa322')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa325')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa327')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa328')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa32b')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa32d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa32e')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa32f')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa330')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa331')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa334')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa335')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa340')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa346')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa34a')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa34b')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa34d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa351')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa354')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa355')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa356')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa357')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa359')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa35a')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa35c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa35d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa366')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa367')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa369')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa36a')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa36d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa371')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa374')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa375')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa379')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa37b')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa37c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa37f')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa384')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa387')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa389')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa38b')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa396')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa39c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3a0')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3a1')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3a4')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3aa')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3ab')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3ad')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3b6')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3b7')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3ba')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3bd')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3bf')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3c2')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3c3')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3c7')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3ca')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3ce')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3cf')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3d0')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3d4')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3d6')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3d7')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3d8')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3d9')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3da')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3db')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3e1')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3e5')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3e7')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3e8')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3ed')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3f6')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3f8')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3f9')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3fe')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa3ff')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa400')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa401')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa402')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa403')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa405')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa406')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa40b')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa40c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa40d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa40e')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa411')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa413')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa414')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa415')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa41a')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa420')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa422')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa423')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa424')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa425')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa426')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa428')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa42d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa42e')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa438')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa439')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa43c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa440')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa446')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa449')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa451')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa452')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa453')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa45c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa47d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa485')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa489')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa48e')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa48f')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa490')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa492')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa495')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa497')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa498')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa499')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa49a')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa49b')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4ac')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4b0')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4bc')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4be')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4c3')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4c4')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4d0')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4d1')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4d5')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4da')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4dc')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4de')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4df')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4e1')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4e9')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4fa')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa4fe')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa508')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa509')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa50f')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa514')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa519')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa51c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa520')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa525')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa527')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa529')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa52d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa536')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa539')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa53b')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa53c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa53d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa540')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa542')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa543')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa544')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa547')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa549')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa54a')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa54b')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa550')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa551')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa552')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa554')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa555')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa557')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa558')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa559')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa55a')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa55d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa562')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa563')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa568')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa56a')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa56c')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa56d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa572')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa576')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa579')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa57d')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa589')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa58e')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa590')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa591')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa596')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa597')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5a4')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5ae')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5af')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5b7')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5c4')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5c9')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5ce')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5d0')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5d4')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5d9')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5da')}
# {'_id': ObjectId('6409335b3b86c0dfb8afa5e8')}
# {'BussinessTypeID': 1, '_id': ObjectId('640937d77adc30b57f1c2b78')}
# {'_id': ObjectId('640d00e62e5ad060df63cf05')}
# {'_id': ObjectId('640d016a2e5ad060df63cf07')}
# {'_id': ObjectId('640d034c2e5ad060df63cf09')}
# {'_id': ObjectId('640d03a02e5ad060df63cf0a')}
# {'_id': ObjectId('640d05e42e5ad060df63cf0c')}
# {'_id': ObjectId('640d098c2e5ad060df63cf0e')}
# {'_id': ObjectId('640d09c32e5ad060df63cf10')}
# {'_id': ObjectId('640fefcd656e16219ea080f0')}
# {'_id': ObjectId('640ff688656e16219ea080f2')}
# {'_id': ObjectId('640ff6cc656e16219ea080f4')}

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({'BusinessName': 'Penang Flavours'}, {'$set':{'BussinessTypeID':1}})

# %%
# Confirm that the new restaurant was updated
pprint(establishments.find_one({'BusinessName': 'Penang Flavours'}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'BussinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('640937d77adc30b57f1c2b78'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
uk_food_db.establishments.delete_many(
    {'LocalAuthorityName': 'Dover'}
)

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6409334d3b86c0dfb8af0d6e'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for latitude & longitude
establishments.update_many({}, [ {'$set':{ "geocode.latitude" : {'$toDouble': "$geocode.latitude"}}}, 
                                {'$set':{ "geocode.longitude" : {'$toDouble': "$geocode.longitude"}}}])

# %%
# Check that the coordinates are now numbers
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6409334d3b86c0dfb8af0d6e'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
